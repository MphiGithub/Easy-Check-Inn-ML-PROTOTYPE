# %%
# Install dependencies if not already installed
# !pip install opencv-python
# !pip install deepface
# !pip install scikit-image
# Out:
# Requirement already satisfied: opencv-python in c:\users\matth\miniconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\matth\miniconda3\lib\site-packages (from opencv-python) (1.24.2)
# Requirement already satisfied: deepface in c:\users\matth\miniconda3\lib\site-packages (0.0.78)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (2.2.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (9.4.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (1.24.2)
# Requirement already satisfied: keras>=2.2.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (2.11.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (1.5.2)
# Requirement already satisfied: fire>=0.4.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (2.11.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (4.7.0.68)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (4.6.3)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\matth\miniconda3\lib\site-packages (from deepface) (4.64.1)
# Requirement already satisfied: termcolor in c:\users\matth\miniconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.2.0)
# Requirement already satisfied: six in c:\users\matth\miniconda3\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: click>=8.0 in c:\users\matth\miniconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\matth\miniconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\matth\miniconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\matth\miniconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\matth\miniconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: requests[socks] in c:\users\matth\miniconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: filelock in c:\users\matth\miniconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\matth\miniconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matth\miniconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2022.7)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (2.11.2)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (23.1.21)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.51.1)
# Requirement already satisfied: setuptools in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (65.5.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.30.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (15.0.6.1)
# Requirement already satisfied: packaging in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (22.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\matth\miniconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: colorama in c:\users\matth\miniconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matth\miniconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\matth\miniconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matth\miniconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\matth\miniconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\matth\miniconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matth\miniconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\matth\miniconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\matth\miniconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\matth\miniconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\matth\miniconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (2.16.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\matth\miniconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matth\miniconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\matth\miniconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\matth\miniconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\matth\miniconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\matth\miniconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\matth\miniconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\matth\miniconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Requirement already satisfied: scikit-image in c:\users\matth\miniconda3\lib\site-packages (0.19.3)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (1.24.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (2.25.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (1.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (22.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\matth\miniconda3\lib\site-packages (from scikit-image) (2023.2.3)
# Requirement already satisfied: imageio[pyav] in c:\users\matth\miniconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: numpy in c:\users\matth\miniconda3\lib\site-packages (from imageio[pyav]) (1.24.2)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\matth\miniconda3\lib\site-packages (from imageio[pyav]) (9.4.0)
# Collecting av
#   Downloading av-10.0.0-cp310-cp310-win_amd64.whl (25.3 MB)
#      --------------------------------------- 25.3/25.3 MB 50.4 MB/s eta 0:00:00
# Installing collected packages: av
# Successfully installed av-10.0.0

# %%
# Imports
import os
import cv2
import pickle
from deepface import DeepFace

import pandas as pd
import numpy as np

from sklearnex import patch_sklearn 
patch_sklearn()

from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage.io import imread

# %% [markdown]
# ## Mask Detection Code

# %%
# References: CPSC330 lectures https://github.com/UBC-CS/cpsc330-2022W2/tree/main/lectures/Giulia
# and https://medium.com/analytics-vidhya/image-classification-using-machine-learning-support-vector-machine-svm-dc7a0ec92e01

# Set up the dataset. 
categories = ["with_mask", "without_mask"]
flattened_data_arr=[]
target_data_arr=[]

dataset_dir='Mask Detection Dataset'

for i in categories:
  path=os.path.join(dataset_dir, i)
  for img in os.listdir(path):
    img_arr =imread(os.path.join(path,img))
    img_resized=resize(img_arr,(150,150,3))
    flattened_data_arr.append(img_resized.flatten())
    target_data_arr.append(categories.index(i))
flat_data=np.array(flattened_data_arr)
target=np.array(target_data_arr)
df=pd.DataFrame(flat_data)
df['y']=target
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.641322  0.691860  0.697347  0.655210  0.701109  0.707306  0.655569
# 1     0.827512  0.653180  0.491059  0.841284  0.650468  0.493711  0.850990
# 2     0.730885  0.812375  0.874986  0.726015  0.806514  0.877890  0.720749
# 3     0.450844  0.427905  0.386078  0.451091  0.428018  0.386253  0.450431
# 4     0.439992  0.487577  0.478946  0.506197  0.552353  0.556935  0.498054
# ...        ...       ...       ...       ...       ...       ...       ...
# 4087  0.961500  0.975149  0.940524  0.944469  0.951834  0.925106  0.972149
# 4088  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4089  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4090  0.869253  0.871993  0.888193  0.854429  0.853327  0.861062  0.968035
# 4091  0.942600  0.934664  0.928169  0.965214  0.932423  0.936192  0.990179
#
#              7         8         9  ...     67491     67492     67493  \
# 0     0.710097  0.712088  0.655129  ...  0.647395  0.677198  0.721020
# 1     0.654826  0.499284  0.844877  ...  0.503734  0.537413  0.650407
# 2     0.801226  0.870588  0.712330  ...  0.494761  0.185948  0.188471
# 3     0.427394  0.385625  0.450051  ...  0.427337  0.505048  0.506117
# 4     0.549710  0.556630  0.472088  ...  0.121137  0.128980  0.125058
# ...        ...       ...       ...  ...       ...       ...       ...
# 4087  0.973504  0.956154  0.982551  ...  0.611353  0.589679  0.509226
# 4088  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4089  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4090  0.955203  0.958218  0.963141  ...  0.132202  0.146528  0.056075
# 4091  0.941610  0.951308  0.981825  ...  0.130487  0.149674  0.140219
#
#          67494     67495     67496     67497     67498     67499  Target
# 0     0.708684  0.737299  0.774451  0.710895  0.742172  0.759660       0
# 1     0.575583  0.610433  0.724787  0.506555  0.547418  0.662619       0
# 2     0.521366  0.187717  0.198982  0.515518  0.164593  0.181504       0
# 3     0.470398  0.547979  0.549008  0.476078  0.553266  0.553292       0
# 4     0.119263  0.127052  0.123157  0.159101  0.163711  0.161406       0
# ...        ...       ...       ...       ...       ...       ...     ...
# 4087  0.617805  0.630654  0.504080  0.600988  0.635056  0.474957       1
# 4088  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000       1
# 4089  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000       1
# 4090  0.477588  0.479983  0.493963  0.889212  0.876364  0.941412       1
# 4091  0.484235  0.542883  0.537898  0.802279  0.904644  0.898013       1
#
# [4092 rows x 67501 columns]

# %%
# Split the dataset
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
# Fit the model and find good hyperparameters
hyperparameters = {'C':[0.1, 1, 10, 100],
                   'gamma':[0.0001, 0.001, 0.1, 1]}

svc=svm.SVC(probability=True)

model = GridSearchCV(svc, hyperparameters)
model.fit(X_train, y_train)
model.best_params_

# %%
pickle.dump(model,open('img_model.p','wb'))
print("Saved model to img_model.p")

# %%
# Dataset taken from https://github.com/chandrikadeb7/Face-Mask-Detection
def check_mask(path):
    # Use ML to check for a mask
    return 0

# %% [markdown]
# ## Face Recognition Code

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
]

def verify_guest(path, room_num):
    # check_mask returns 1 for masked guests, 0 otherwise
    has_mask = check_mask(path) 
    if has_mask:
        return 0, "Please take off your face mask and try again." # Mask detected
    else:
        room_dir = f"Face Recognition Data/room_{room_num}"
        # Iterate through each photo in the list of registered guests
        for filename in os.listdir(room_dir):
            f = os.path.join(room_dir, filename)
            if os.path.isfile(f):
                curr_result = DeepFace.verify(img1_path = path, 
                                  img2_path = f, 
                                  model_name = models[0]
                              )
                if curr_result["verified"]:
                    return 1, "Welcome, guest."
    return 0, "Please try again." # No match

# %%
# DeepFace.verify(img1_path = "room_1/trump_1.jpg", 
#                 img2_path = "test_inputs/room_1/trump_2.jpg", 
#                 model_name = models[0]
#             )
verify_guest("Face Recognition Data/test_inputs/room_1/trump_2.jpg", 1)
# Out:
# (1, 'Welcome, guest.')
